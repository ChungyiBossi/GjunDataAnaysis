# %% [markdown]
# <a href="https://colab.research.google.com/github/ChungyiBossi/GjunDataAnaysis/blob/main/coffee_shop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 安裝pandas

# %%
# !pip install pandas

# %% [markdown]
# ## 探索資料

# %%
# import pandas as pd
# from IPython.display import display

# %%
# 程式碼掛載GD
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 顯示資料框的前幾行
import pandas as pd

# 讀取 CSV 檔案
# df = pd.read_csv('/content/coffee_shop.csv') # 手動上傳的讀取方式
df = pd.read_csv('/content/drive/MyDrive/工作/2026/巨匠北認-商業資料分析/0718/coffee_shop.csv') # DataFrame

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# 顯示資料框的前幾列
df.head()
# print(df.head()) # 如果再vscode
# Out:
#    OrderID        Date     Product Category  Price  Quantity Member  \
# 0     1001  2026-07-01       Latte   Coffee    120         2    Yes
# 1     1002  2026-07-01   Americano   Coffee     90         1     No
# 2     1003  2026-07-01  Cappuccino   Coffee    130         1    Yes
# 3     1004  2026-07-01  Cheesecake  Dessert    150         2     No
# 4     1005  2026-07-01      Cookie  Dessert     60         3    Yes
#
#        Payment
# 0  Credit Card
# 1         Cash
# 2   Mobile Pay
# 3  Credit Card
# 4         Cash

# %%
print(df.head())
# Out:
#    OrderID        Date     Product Category  Price  Quantity Member  \
# 0     1001  2026-07-01       Latte   Coffee    120         2    Yes
# 1     1002  2026-07-01   Americano   Coffee     90         1     No
# 2     1003  2026-07-01  Cappuccino   Coffee    130         1    Yes
# 3     1004  2026-07-01  Cheesecake  Dessert    150         2     No
# 4     1005  2026-07-01      Cookie  Dessert     60         3    Yes
#
#        Payment
# 0  Credit Card
# 1         Cash
# 2   Mobile Pay
# 3  Credit Card
# 4         Cash

# %%
len(df) # df.size
# Out:
# 30

# %%
# 取單行
df['Product'].head()
# Out:
# 0         Latte
# 1     Americano
# 2    Cappuccino
# 3    Cheesecake
# 4        Cookie
# Name: Product, dtype: object

# %%
# 選擇某幾行
# 假設取用 Product, Category, Price

df[['Product', 'Category', 'Price', 'Quantity']].head() # index為一個List
# Out:
#       Product Category  Price  Quantity
# 0       Latte   Coffee    120         2
# 1   Americano   Coffee     90         1
# 2  Cappuccino   Coffee    130         1
# 3  Cheesecake  Dessert    150         2
# 4      Cookie  Dessert     60         3

# %%
df['TotalPrice'] = df['Price'] * df['Quantity']
print(type(df['TotalPrice']))
df.head()
# Out:
# <class 'pandas.core.series.Series'>
#    OrderID        Date     Product Category  Price  Quantity Member  \
# 0     1001  2026-07-01       Latte   Coffee    120         2    Yes
# 1     1002  2026-07-01   Americano   Coffee     90         1     No
# 2     1003  2026-07-01  Cappuccino   Coffee    130         1    Yes
# 3     1004  2026-07-01  Cheesecake  Dessert    150         2     No
# 4     1005  2026-07-01      Cookie  Dessert     60         3    Yes
#
#        Payment  TotalPrice
# 0  Credit Card         240
# 1         Cash          90
# 2   Mobile Pay         130
# 3  Credit Card         300
# 4         Cash         180

# %%
groups = df.groupby('Product')
type(groups), len(groups)
# Out:
# (pandas.core.groupby.generic.DataFrameGroupBy, 8)

# %%
for name, group_data in groups:
    print(name, len(group_data))
    display(group_data)
    print()
# Out:
# Americano 5
#     OrderID        Date    Product Category  Price  Quantity Member  \
# 1      1002  2026-07-01  Americano   Coffee     90         1     No
# 8      1009  2026-07-02  Americano   Coffee     90         2     No
# 16     1017  2026-07-04  Americano   Coffee     90         3    Yes
# 22     1023  2026-07-06  Americano   Coffee     90         2    Yes
# 28     1029  2026-07-07  Americano   Coffee     90         2    Yes
#
#         Payment  TotalPrice
# 1          Cash          90
# 8   Credit Card         180
# 16         Cash         270
# 22  Credit Card         180
# 28         Cash         180
# Brownie 3
#     OrderID        Date  Product Category  Price  Quantity Member  \
# 7      1008  2026-07-02  Brownie  Dessert     80         2    Yes
# 18     1019  2026-07-05  Brownie  Dessert     80         2    Yes
# 27     1028  2026-07-07  Brownie  Dessert     80         3     No
#
#         Payment  TotalPrice
# 7          Cash         160
# 18  Credit Card         160
# ...

# %%
# 迭代每個 'Product' 分組並顯示其前幾筆資料
for product_name, group_data in df.groupby('Product'):
    print(f"\n產品: {product_name}, 共 {len(group_data)} 筆。")
    display(group_data.head(n=10)) # 顯示每個組的前10筆資料
    print()

type(group_data)
# Out:
# 產品: Americano, 共 5 筆。
#     OrderID        Date    Product Category  Price  Quantity Member  \
# 1      1002  2026-07-01  Americano   Coffee     90         1     No
# 8      1009  2026-07-02  Americano   Coffee     90         2     No
# 16     1017  2026-07-04  Americano   Coffee     90         3    Yes
# 22     1023  2026-07-06  Americano   Coffee     90         2    Yes
# 28     1029  2026-07-07  Americano   Coffee     90         2    Yes
#
#         Payment  TotalPrice
# 1          Cash          90
# 8   Credit Card         180
# 16         Cash         270
# 22  Credit Card         180
# 28         Cash         180
# 產品: Brownie, 共 3 筆。
#     OrderID        Date  Product Category  Price  Quantity Member  \
# 7      1008  2026-07-02  Brownie  Dessert     80         2    Yes
# 18     1019  2026-07-05  Brownie  Dessert     80         2    Yes
# 27     1028  2026-07-07  Brownie  Dessert     80         3     No
#
#         Payment  TotalPrice
# 7          Cash         160
# ...

# %%
group_member_yes = df.groupby('Member').get_group('Yes')
print(len(group_member_yes))
display(group_member_yes.head())
# Out:
# 18
#    OrderID        Date     Product Category  Price  Quantity Member  \
# 0     1001  2026-07-01       Latte   Coffee    120         2    Yes
# 2     1003  2026-07-01  Cappuccino   Coffee    130         1    Yes
# 4     1005  2026-07-01      Cookie  Dessert     60         3    Yes
# 6     1007  2026-07-02       Latte   Coffee    120         1    Yes
# 7     1008  2026-07-02     Brownie  Dessert     80         2    Yes
#
#        Payment  TotalPrice
# 0  Credit Card         240
# 2   Mobile Pay         130
# 4         Cash         180
# 6  Credit Card         120
# 7         Cash         160

# %%
# 第一種寫法：groupby後，取得 'Latte' group
latte_group = df.groupby('Product').get_group('Latte')
display(latte_group.head())
# Out:
#     OrderID        Date Product Category  Price  Quantity Member      Payment  \
# 0      1001  2026-07-01   Latte   Coffee    120         2    Yes  Credit Card
# 6      1007  2026-07-02   Latte   Coffee    120         1    Yes  Credit Card
# 10     1011  2026-07-03   Latte   Coffee    120         2    Yes  Credit Card
# 17     1018  2026-07-05   Latte   Coffee    120         1     No   Mobile Pay
# 23     1024  2026-07-06   Latte   Coffee    120         3     No   Mobile Pay
#
#     TotalPrice
# 0          240
# 6          120
# 10         240
# 17         120
# 23         360

# %%
# 第二種寫法: 一列一列比較
filter_latte = df[ df['Product']=='Latte' ]
display(filter_latte.head())
# Out:
#     OrderID        Date Product Category  Price  Quantity Member      Payment  \
# 0      1001  2026-07-01   Latte   Coffee    120         2    Yes  Credit Card
# 6      1007  2026-07-02   Latte   Coffee    120         1    Yes  Credit Card
# 10     1011  2026-07-03   Latte   Coffee    120         2    Yes  Credit Card
# 17     1018  2026-07-05   Latte   Coffee    120         1     No   Mobile Pay
# 23     1024  2026-07-06   Latte   Coffee    120         3     No   Mobile Pay
#
#     TotalPrice
# 0          240
# 6          120
# 10         240
# 17         120
# 23         360

# %%
# Latte + Credit Card
card_latte = df[(df['Product']=='Latte')&(df['Payment']=='Credit Card')]
display(card_latte)
# Out:
#     OrderID        Date Product Category  Price  Quantity Member      Payment  \
# 0      1001  2026-07-01   Latte   Coffee    120         2    Yes  Credit Card
# 6      1007  2026-07-02   Latte   Coffee    120         1    Yes  Credit Card
# 10     1011  2026-07-03   Latte   Coffee    120         2    Yes  Credit Card
# 29     1030  2026-07-07   Latte   Coffee    120         2    Yes  Credit Card
#
#     TotalPrice
# 0          240
# 6          120
# 10         240
# 29         240

# %%
x = [1,3,5,7,10]
sum(x)
# Out:
# 26

# %%
# 計算每個品項的銷售數量並找出賣的最好的品項
for product_name, group_data in df.groupby('Product'):
    total_quantity = group_data['Quantity'].sum() # 取總和
    print(f"產品: {product_name}, 總銷售數量: {total_quantity}")
# Out:
# 產品: Americano, 總銷售數量: 10
# 產品: Brownie, 總銷售數量: 7
# 產品: Cappuccino, 總銷售數量: 5
# 產品: Cheesecake, 總銷售數量: 5
# 產品: Cookie, 總銷售數量: 9
# 產品: Latte, 總銷售數量: 11
# 產品: Mocha, 總銷售數量: 4
# 產品: Tea, 總銷售數量: 10

# %%
df.groupby('Product')['Quantity'].sum()
# Out:
# Product
# Americano     10
# Brownie        7
# Cappuccino     5
# Cheesecake     5
# Cookie         9
# Latte         11
# Mocha          4
# Tea           10
# Name: Quantity, dtype: int64

# %%
# 計算總銷售額最好的品項
for product_name, group_data in df.groupby('Product'):
    total_quantity = group_data['Quantity'].sum() # 取總和
    item_price = group_data['Price'].iloc[0] # 取單價
    # display(group_data.iloc[0])
    print(f"產品: {product_name}, 總銷售額: {total_quantity * item_price}")
# Out:
# 產品: Americano, 總銷售額: 900
# 產品: Brownie, 總銷售額: 560
# 產品: Cappuccino, 總銷售額: 650
# 產品: Cheesecake, 總銷售額: 750
# 產品: Cookie, 總銷售額: 540
# 產品: Latte, 總銷售額: 1320
# 產品: Mocha, 總銷售額: 560
# 產品: Tea, 總銷售額: 700

# %% [markdown]
# ### 練習題
#
# 請根據 `df` 這個 DataFrame，完成以下操作：
#
# ---

# %% [markdown]
# #### 題目一：找出每個 `Category` 的總銷售額
#
# 計算每個 `Category` (例如: Coffee, Dessert) 的總銷售額。總銷售額是 `Price` 乘以 `Quantity` 的總和。

# %%
# # 提示：您可以先創建一個新的 'TotalSales' 欄位，然後再分組加總。
df['TotalSales'] = df['Price'] * df['Quantity']
category_sales = df.groupby('Category')['TotalSales'].sum()
display(category_sales)
# Out:
# Category
# Coffee     3430
# Dessert    1850
# Drink       700
# Name: TotalSales, dtype: int64

# %%
df['TotalSales'] = df['Price'] * df['Quantity']
for group_name, group_data in df.groupby('Category'):
    total_sales = group_data['TotalSales'].sum()
    print(f"Category: {group_name}, Total Sales: {total_sales}")
# Out:
# Category: Coffee, Total Sales: 3430
# Category: Dessert, Total Sales: 1850
# Category: Drink, Total Sales: 700

# %% [markdown]
# #### 題目二：計算每個 `Product` 的平均單價
#
# 找出每個 `Product` 的平均 `Price`。

# %%
# 提示：使用 groupby('Product') 和 .mean()。
avg_price_per_product = df.groupby('Product')['Price'].mean()
print("Data type: ", type(avg_price_per_product))
display(avg_price_per_product)
# Out:
# Data type:  <class 'pandas.core.series.Series'>
# Product
# Americano      90.0
# Brownie        80.0
# Cappuccino    130.0
# Cheesecake    150.0
# Cookie         60.0
# Latte         120.0
# Mocha         140.0
# Tea            70.0
# Name: Price, dtype: float64

# %% [markdown]
# #### 題目三：找出 `Member` 為 `Yes` 的所有訂單
#
# 篩選出所有 `Member` 欄位為 `'Yes'` 的訂單，並顯示前5筆資料。

# %%
# 提示：使用布林索引來篩選資料。
members_only_orders = df[df['Member'] == 'Yes']
display(members_only_orders)
# Out:
#     OrderID        Date     Product Category  Price  Quantity Member  \
# 0      1001  2026-07-01       Latte   Coffee    120         2    Yes
# 2      1003  2026-07-01  Cappuccino   Coffee    130         1    Yes
# 4      1005  2026-07-01      Cookie  Dessert     60         3    Yes
# 6      1007  2026-07-02       Latte   Coffee    120         1    Yes
# 7      1008  2026-07-02     Brownie  Dessert     80         2    Yes
# 9      1010  2026-07-03         Tea    Drink     70         3    Yes
# 10     1011  2026-07-03       Latte   Coffee    120         2    Yes
# 12     1013  2026-07-03       Mocha   Coffee    140         1    Yes
# 14     1015  2026-07-04  Cappuccino   Coffee    130         2    Yes
# 16     1017  2026-07-04   Americano   Coffee     90         3    Yes
# 18     1019  2026-07-05     Brownie  Dessert     80         2    Yes
# 19     1020  2026-07-05         Tea    Drink     70         4    Yes
# 21     1022  2026-07-06      Cookie  Dessert     60         2    Yes
# ...

# %%
# 提示：使用布林索引來篩選資料。
# 記得要用 & 而非 'and'
# members_only_orders = df[(df['Member'] == 'Yes') & (df['Category'] == 'Coffee')]
# display(members_only_orders.head())

# %%
# 記得要用 | 而非 'or'
# members_only_orders = df[(df['Member'] == 'Yes') | (df['Category'] == 'Coffee')]
# display(members_only_orders)

# %% [markdown]
# #### 題目四：哪個 `Payment` 方式最受歡迎？
#
# 計算每種 `Payment` 方式出現的次數，找出最常用的支付方式。

# %%
# 提示：可以使用 .value_counts() 方法。
payment_counts = df['Payment'].value_counts() # 用來計算類別的"出現"次數
display(payment_counts)
# Out:
# Payment
# Credit Card    13
# Cash           10
# Mobile Pay      7
# Name: count, dtype: int64

# %%
df.groupby('Payment').size()
# Out:
# Payment
# Cash           10
# Credit Card    13
# Mobile Pay      7
# dtype: int64

# %% [markdown]
# ## 繪圖

# %%
# !pip install matplotlib
# !pip install seaborn

# %% [markdown]
# ### 1. 繪製每個產品的總銷售數量長條圖
#
# 首先，我們來看看每個產品的總銷售數量分佈。

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 設定圖表風格
sns.set_style("whitegrid")

# 計算每個產品的總銷售數量 (若尚未計算，則在此處重新計算)
product_sales = df.groupby('Product')['Quantity'].sum().sort_values(ascending=False)
display(product_sales)
# Out:
# Product
# Latte         11
# Americano     10
# Tea           10
# Cookie         9
# Brownie        7
# Cappuccino     5
# Cheesecake     5
# Mocha          4
# Name: Quantity, dtype: int64

# %%
# 繪製長條圖
plt.figure(figsize=(10, 6)) # 創建圖
sns.barplot(
    x=product_sales.index,
    y=product_sales.values,
    palette='coolwarm'
)
plt.title('Amount', fontsize=16) # 圖表名稱
plt.xlabel('Product Name', fontsize=12) # X軸名稱
plt.ylabel('Total # saled item', fontsize=12) # Y軸名稱
plt.xticks(rotation=45, ha='right') # 控制著刻度標籤的水平對齊方式，如果是right意謂刻度標籤的右邊會對其bar的中心。
plt.savefig('product_sales.png') # before show fig
plt.show()
# Out:
# /tmp/ipykernel_979/1042968999.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ### 2. 繪製每個類別的銷售額圓餅圖
#
# 接下來，我們來看看不同產品類別的銷售額佔比。

# %%
df['TotalSales'] = df['Price'] * df['Quantity']

category_sales = df.groupby('Category')['TotalSales'].sum()

plt.figure(figsize=(8, 8))
plt.pie(
    category_sales,
    labels=category_sales.index,
    autopct='%1.0f%%',
    # textprops={'fontsize': 20} # 增加百分比文字大小
)
plt.title('Sales Mix', fontsize=16)
plt.ylabel('')
plt.savefig('category_sales_pie.png')
plt.show()

# %%
# df['TotalSales'] = df['Price'] * df['Quantity']

product_sales = df.groupby('Product')['TotalSales'].sum()

plt.figure(figsize=(8, 8))
plt.pie(
    product_sales,
    labels=product_sales.index,
    autopct='%1.0f%%',
    # textprops={'fontsize': 20} # 增加百分比文字大小
)
plt.title('Sales Mix', fontsize=16)
plt.ylabel('')
plt.savefig('product_sales_pie.png')
plt.show()

# %% [markdown]
# ### 3. 比較不同會員類別的總銷售額差異
#
# 現在，讓我們來看看會員和非會員的總銷售額有何不同。

# %%
# 計算會員與非會員的總銷售額
member_sales = df.groupby('Member')['TotalSales'].sum()

# 繪製圓餅圖
plt.figure(figsize=(8, 8))
plt.pie(
    member_sales.values,
    labels=member_sales.index,
    autopct='%1.2f%%',
    textprops={'fontsize': 14} # 增加百分比文字大小
)
plt.title('Total Sales by Member Type', fontsize=16)
plt.ylabel('')
plt.savefig('member_sales_pie.png')
plt.show()

# %% [markdown]
# 要賺大錢 == 會員多一點?

# %% [markdown]
# ### 4. 分析會員與非會員的商品種類偏好
#
# 現在，我們將進一步分析會員和非會員在不同商品類別上的消費偏好。

# %% [markdown]
# #### 4-1. 會員 vs 產品類別

# %%
# 計算每個會員類別中，各商品類別的總銷售額
print("Groupby and sum")
member_category_sales = df.groupby(['Member', 'Category'])['TotalSales'].sum()
display(member_category_sales)
# Out:
# Groupby and sum
# Member  Category
# No      Coffee      1170
#         Dessert      930
#         Drink        210
# Yes     Coffee      2260
#         Dessert      920
#         Drink        490
# Name: TotalSales, dtype: int64

# %%
print("Unstack")
member_category_sales = member_category_sales.unstack()
display(member_category_sales)
# Out:
# Unstack
# Category  Coffee  Dessert  Drink
# Member
# No          1170      930    210
# Yes         2260      920    490

# %%
print("Reset Index")
# 繪製堆疊長條圖或分組長條圖
# 將 DataFrame 轉換為適合繪圖的格式
member_category_sales_melted = member_category_sales.reset_index()
display(member_category_sales_melted)
# Out:
# Reset Index
# Category Member  Coffee  Dessert  Drink
# 0            No    1170      930    210
# 1           Yes    2260      920    490

# %%
print("Melt")
member_category_sales_melted = member_category_sales_melted.melt('Member', var_name='Category', value_name='TotalSales')
display(member_category_sales_melted)
# Out:
# Melt
#   Member Category  TotalSales
# 0     No   Coffee        1170
# 1    Yes   Coffee        2260
# 2     No  Dessert         930
# 3    Yes  Dessert         920
# 4     No    Drink         210
# 5    Yes    Drink         490

# %%
plt.figure(figsize=(12, 7))
sns.barplot(
    x='Category',
    y='TotalSales',
    hue='Member',
    data=member_category_sales_melted, # data 給 dataframe, x & y 就可以給欄位名稱
    palette='viridis'
)
plt.title('Total Sales by Category and Member Type', fontsize=16)
plt.xlabel('Category', fontsize=12)
plt.ylabel('Total Sales Amount', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Member')
plt.savefig('member_category_preference.png') # 儲存圖片
plt.show()

# %% [markdown]
# ### 4-2. 會員 vs 品項

# %%
# 計算每個會員類別中，各商品類別的總銷售額
print("Groupby and sum")
member_product_sales = df.groupby(['Member', 'Product'])['TotalSales'].sum()
display(member_product_sales)
# Out:
# Groupby and sum
# Member  Product
# No      Americano     270
#         Brownie       240
#         Cheesecake    450
#         Cookie        240
#         Latte         480
#         Mocha         420
#         Tea           210
# Yes     Americano     630
#         Brownie       320
#         Cappuccino    650
#         Cheesecake    300
#         Cookie        300
#         Latte         840
#         Mocha         140
#         Tea           490
# Name: TotalSales, dtype: int64

# %%
print("Unstack")
member_product_sales = member_product_sales.unstack()
display(member_product_sales)
# Out:
# Unstack
# Product  Americano  Brownie  Cappuccino  Cheesecake  Cookie  Latte  Mocha  \
# Member
# No           270.0    240.0         NaN       450.0   240.0  480.0  420.0
# Yes          630.0    320.0       650.0       300.0   300.0  840.0  140.0
#
# Product    Tea
# Member
# No       210.0
# Yes      490.0

# %%
member_product_sales = member_product_sales.reset_index()
member_product_sales_melted = member_product_sales.melt(
    'Member', var_name='Product', value_name='TotalSales'
)
display(member_product_sales_melted)
# Out:
#    Member     Product  TotalSales
# 0      No   Americano       270.0
# 1     Yes   Americano       630.0
# 2      No     Brownie       240.0
# 3     Yes     Brownie       320.0
# 4      No  Cappuccino         NaN
# 5     Yes  Cappuccino       650.0
# 6      No  Cheesecake       450.0
# 7     Yes  Cheesecake       300.0
# 8      No      Cookie       240.0
# 9     Yes      Cookie       300.0
# 10     No       Latte       480.0
# 11    Yes       Latte       840.0
# 12     No       Mocha       420.0
# 13    Yes       Mocha       140.0
# 14     No         Tea       210.0
# 15    Yes         Tea       490.0

# %%
plt.figure(figsize=(12, 7))
sns.barplot(
    x='Product',
    y='TotalSales',
    hue='Member',
    data=member_product_sales_melted, # data 給 dataframe, x & y 就可以給欄位名稱
    palette='viridis'
)
plt.title('Total Sales by Product and Member Type', fontsize=16)
plt.xlabel('Product', fontsize=12)
plt.ylabel('Total Sales Amount', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Member')
plt.savefig('member_product_preference.png') # 儲存圖片
plt.show()

# %% [markdown]
# ### 5.結論

# %% [markdown]
# 1.    會員喜歡 Cappuccino & Latte
# 2.   非會員喜歡 Mocha & Cheese Cake

# %% [markdown]
# ### 練習題
#
# 請根據 `df` 這個 DataFrame，完成以下操作：
#
# ---

# %% [markdown]
# #### 題目五：找出銷量前三名的產品
#
# 計算每個 `Product` 的總銷售數量，並找出銷量最高的3個產品。

# %%
# 提示：使用 groupby('Product') 和 .sum()，然後使用 .nlargest()。
# top_3_products = df.groupby('Product')['Quantity'].sum().nlargest(3)
# display(top_3_products)

# %% [markdown]
# #### 題目六：計算每週日的總銷售額
#
# 首先，將 'Date' 欄位轉換為日期時間格式，然後計算出是星期幾，最後計算每個星期幾的總銷售額。

# %%
# 提示：使用 pd.to_datetime 轉換 'Date'，然後使用 .
# dt.dayofweek (0=星期一, 6=星期日) 或 .dt.day_name()。

# df['Date'] = pd.to_datetime(df['Date'])
# df['DayOfWeek'] = df['Date'].dt.day_name()
# sales_by_day = df.groupby('DayOfWeek')['TotalSales'].sum()
# display(sales_by_day)

# %% [markdown]
# #### 題目七：比較會員與非會員的平均購買數量
#
# 計算會員 (`Member` 為 'Yes') 和非會員 (`Member` 為 'No') 的平均單筆訂單購買數量 (`Quantity`) 各是多少。

# %%
# 提示：使用 groupby('Member') 和 .mean()。
# avg_quantity_by_member = df.groupby('Member')['Quantity'].mean()
# display(avg_quantity_by_member)
